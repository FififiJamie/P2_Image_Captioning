# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will use your trained model to generate captions for images in the test dataset.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Get Data Loader for Test Dataset
# - [Step 2](#step2): Load Trained Models
# - [Step 3](#step3): Finish the Sampler
# - [Step 4](#step4): Clean up Captions
# - [Step 5](#step5): Generate Predictions!

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Get Data Loader for Test Dataset
#
# Before running the code cell below, define the transform in `transform_test` that you would like to use to pre-process the test images.
#
# Make sure that the transform that you define here agrees with the transform that you used to pre-process the training images (in **2_Training.ipynb**).  For instance, if you normalized the training images, you should also apply the same normalization procedure to the test images.

# %%
print(torch.__version__)
# Out:
# 1.0.1.post2

# %%
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from torchvision import transforms

# TODO #1: Define a transform to pre-process the testing images.
transform_test = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

#-#-#-# Do NOT modify the code below this line. #-#-#-#

# Create the data loader.
data_loader = get_loader(transform=transform_test,    
                         mode='test')
# Out:
# Vocabulary successfully loaded from vocab.pkl file!

# %% [markdown]
# Run the code cell below to visualize an example test image, before pre-processing is applied.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Obtain sample image before and after pre-processing.
orig_image, image = next(iter(data_loader))

# Visualize sample image, before pre-processing.
plt.imshow(np.squeeze(orig_image))
plt.title('example image')
plt.show()

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Load Trained Models
#
# In the next code cell we define a `device` that you will use move PyTorch tensors to GPU (if CUDA is available).  Run this code cell before continuing.

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Before running the code cell below, complete the following tasks.
#
# ### Task #1
#
# In the next code cell, you will load the trained encoder and decoder from the previous notebook (**2_Training.ipynb**).  To accomplish this, you must specify the names of the saved encoder and decoder files in the `models/` folder (e.g., these names should be `encoder-5.pkl` and `decoder-5.pkl`, if you trained the model for 5 epochs and saved the weights after each epoch).
#
# ### Task #2
#
# Plug in both the embedding size and the size of the hidden layer of the decoder corresponding to the selected pickle file in `decoder_file`.

# %%
# Watch for any changes in model.py, and re-load it automatically.
# %load_ext autoreload
# %autoreload 2

import os
import torch
from model import EncoderCNN, DecoderRNN

# TODO #2: Specify the saved models to load.
encoder_file = 'encoder-v2-3.pkl'
decoder_file = 'decoder-v2-3.pkl'

# TODO #3: Select appropriate values for the Python variables below.
embed_size = 128
hidden_size = 128

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)
print(vocab_size)

# Initialize the encoder and decoder, and set each to inference mode.
encoder = EncoderCNN(embed_size)
encoder.eval()
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)
decoder.eval()

# Load the trained weights.
encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))

# Move models to GPU if CUDA is available.
encoder.to(device)
decoder.to(device)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 9955
# torch.FloatTensor
# DecoderRNN(
#   (word_emb): Embedding(9955, 128)
#   (lstm): LSTM(128, 128, batch_first=True)
#   (fc): Linear(in_features=128, out_features=9955, bias=True)
# )

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: Finish the Sampler
#
# Before executing the next code cell, you must write the `sample` method in the `DecoderRNN` class in **model.py**.  This method should accept as input a PyTorch tensor `features` containing the embedded input features corresponding to a single image.
#
# It should return as output a Python list `output`, indicating the predicted sentence.  `output[i]` is a nonnegative integer that identifies the predicted `i`-th token in the sentence.  The correspondence between integers and tokens can be explored by examining either `data_loader.dataset.vocab.word2idx` (or `data_loader.dataset.vocab.idx2word`).
#
# After implementing the `sample` method, run the code cell below.  If the cell returns an assertion error, then please follow the instructions to modify your code before proceeding.  Do **not** modify the code in the cell below.

# %%
# Move image Pytorch Tensor to GPU if CUDA is available.
image = image.to(device)

# Obtain the embedded image features.
features = encoder(image).unsqueeze(1)

# Pass the embedded image features through the model to get a predicted caption.
output, beam_sentences = decoder.sample(features)
print('example output:', output)

assert (type(output)==list), "Output needs to be a Python list" 
assert all([type(x)==int for x in output]), "Output should be a list of integers." 
assert all([x in data_loader.dataset.vocab.idx2word for x in output]), "Each entry in the output needs to correspond to an integer that indicates a token in the vocabulary."
# Out:
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# torch.Size([3, 1, 3])
# example output: [0, 3, 169, 130, 360, 3, 755, 77, 32, 665, 18, 1, 1, 18, 1, 1, 18, 1, 1, 18]

# %% [markdown]
# <a id='step4'></a>
# ## Step 4: Clean up the Captions
#
# In the code cell below, complete the `clean_sentence` function.  It should take a list of integers (corresponding to the variable `output` in **Step 3**) as input and return the corresponding predicted sentence (as a single Python string).

# %%
# TODO #4: Complete the function.
def clean_sentence(output):
    word_list = [data_loader.dataset.vocab.idx2word[int(i)] for i in output]
    s = ' '
    sentence = s.join(word_list)
    # truncate sentence
    # i = sentence.find('<end>') 
    return sentence

# %% [markdown]
# After completing the `clean_sentence` function above, run the code cell below.  If the cell returns an assertion error, then please follow the instructions to modify your code before proceeding.

# %%
sentence = clean_sentence(output)
print('example sentence:', sentence)

assert type(sentence)==str, 'Sentence needs to be a Python string!'

for i in range():
    sentence = clean_sentence(beam_sentences[i])
    print('top {}: {}'.format(i, sentence))
# Out:
# example sentence: <start> a man is holding a skateboard in the air . <end> <end> . <end> <end> . <end> <end> .
# top 0: <start> a man on a skateboard in the air . <end> <end> . <end> <end> . <end> <end> . <end> <end>
# top 1: <start> a man on a skateboard in the air . <end> . <end> <end> . <end> <end> . <end> <end> .
# top 2: <start> a man on a skateboard in the air . <end> <end> . <end> <end> . <end> <end> . <end> .

# %% [markdown]
# <a id='step5'></a>
# ## Step 5: Generate Predictions!
#
# In the code cell below, we have written a function (`get_prediction`) that you can use to use to loop over images in the test dataset and print your model's predicted caption.

# %%
def get_prediction():
    orig_image, image = next(iter(data_loader))
    plt.imshow(np.squeeze(orig_image))
    plt.title('Sample Image')
    plt.show()
    image = image.to(device)
    features = encoder(image).unsqueeze(1)
    output = decoder.sample(features)    
    sentence = clean_sentence(output)
    print(sentence)

# %% [markdown]
# Run the code cell below (multiple times, if you like!) to test how this function works.

# %%
get_prediction()
# Out:
# torch.Size([3, 1, 9955])
# tensor([[[  3,  32,  50]],
#
#         [[  3, 139,  47]],
#
#         [[ 51,   3, 139]]], device='cuda:0')
# -----PPPPPP-----
# tensor([[[9.9993e-01, 9.1251e-06, 8.1819e-07]]], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[7.6346e-01, 3.4944e-02, 2.6157e-02]],
#
#         [[9.2608e-07, 1.9306e-07, 1.4838e-07]],
#
#         [[1.8516e-08, 1.4806e-08, 1.3422e-08]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([0.7635, 0.0349, 0.0262], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([0, 1, 2], device='cuda:0')
# tensor([0, 0, 0], device='cuda:0')
# -----build next search-----
# tensor([ 3, 32, 50], device='cuda:0')
# [[0, 3], [0, 32], [0, 50]]
# tensor([0.7635, 0.0349, 0.0262], device='cuda:0', grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[169,  98,  91]],
#
#         [[169,  98, 253]],
#
#         [[ 51, 454, 253]]], device='cuda:0')
# -----PPPPPP-----
# tensor([0.7635, 0.0349, 0.0262], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([[[0.2241, 0.1402, 0.0422]],
#
#         [[0.0056, 0.0020, 0.0015]],
#
#         [[0.0109, 0.0054, 0.0007]]], device='cuda:0', grad_fn=<MulBackward0>)
# tensor([0.2241, 0.1402, 0.0422], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([0, 1, 2], device='cuda:0')
# tensor([0, 0, 0], device='cuda:0')
# -----build next search-----
# tensor([169,  98,  91], device='cuda:0')
# [[0, 3, 169], [0, 3, 98], [0, 3, 91]]
# tensor([0.2241, 0.1402, 0.0422], device='cuda:0', grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[139,  39, 130]],
#
#         [[139,  39, 130]],
#
#         [[130, 139,  39]]], device='cuda:0')
# -----PPPPPP-----
# tensor([0.2241, 0.1402, 0.0422], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([[[0.0496, 0.0251, 0.0222]],
#
#         [[0.0346, 0.0222, 0.0113]],
#
#         [[0.0058, 0.0054, 0.0042]]], device='cuda:0', grad_fn=<MulBackward0>)
# tensor([0.0496, 0.0346, 0.0251], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([0, 3, 1], device='cuda:0')
# tensor([0, 1, 0], device='cuda:0')
# -----build next search-----
# tensor([139, 139,  39], device='cuda:0')
# [[0, 3, 169, 139], [0, 3, 98, 139], [0, 3, 169, 39]]
# tensor([0.0496, 0.0346, 0.0251], device='cuda:0', grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  3,  39, 319]],
#
#         [[  3,  39, 319]],
#
#         [[  3,  32, 319]]], device='cuda:0')
# -----PPPPPP-----
# tensor([0.0496, 0.0346, 0.0251], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([[[0.0377, 0.0037, 0.0015]],
#
#         [[0.0270, 0.0028, 0.0008]],
#
#         [[0.0168, 0.0020, 0.0018]]], device='cuda:0', grad_fn=<MulBackward0>)
# tensor([0.0377, 0.0270, 0.0168], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([0, 3, 6], device='cuda:0')
# tensor([0, 1, 2], device='cuda:0')
# -----build next search-----
# tensor([3, 3, 3], device='cuda:0')
# [[0, 3, 169, 139, 3], [0, 3, 98, 139, 3], [0, 3, 169, 39, 3]]
# tensor([0.0377, 0.0270, 0.0168], device='cuda:0', grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[755, 453, 899]],
#
#         [[755, 453, 601]],
#
#         [[755, 397, 899]]], device='cuda:0')
# -----PPPPPP-----
# tensor([0.0377, 0.0270, 0.0168], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([[[0.0101, 0.0041, 0.0020]],
#
#         [[0.0064, 0.0029, 0.0015]],
#
#         [[0.0037, 0.0016, 0.0012]]], device='cuda:0', grad_fn=<MulBackward0>)
# tensor([0.0101, 0.0064, 0.0041], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([0, 3, 1], device='cuda:0')
# tensor([0, 1, 0], device='cuda:0')
# -----build next search-----
# tensor([755, 755, 453], device='cuda:0')
# [[0, 3, 169, 139, 3, 755], [0, 3, 98, 139, 3, 755], [0, 3, 169, 139, 3, 453]]
# tensor([0.0101, 0.0064, 0.0041], device='cuda:0', grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[54, 39, 77]],
#
#         [[39, 54, 77]],
#
#         [[39, 77, 21]]], device='cuda:0')
# -----PPPPPP-----
# tensor([0.0101, 0.0064, 0.0041], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([[[0.0027, 0.0025, 0.0008]],
#
#         [[0.0017, 0.0016, 0.0005]],
#
#         [[0.0024, 0.0005, 0.0001]]], device='cuda:0', grad_fn=<MulBackward0>)
# tensor([0.0027, 0.0025, 0.0024], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([0, 1, 6], device='cuda:0')
# tensor([0, 0, 2], device='cuda:0')
# -----build next search-----
# tensor([54, 39, 39], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54], [0, 3, 169, 139, 3, 755, 39], [0, 3, 169, 139, 3, 453, 39]]
# tensor([0.0027, 0.0025, 0.0024], device='cuda:0', grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  3,  32,  39]],
#
#         [[  3,  32, 257]],
#
#         [[  3,  32, 257]]], device='cuda:0')
# -----PPPPPP-----
# tensor([0.0027, 0.0025, 0.0024], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([[[2.0434e-03, 4.1391e-04, 4.7412e-05]],
#
#         [[1.8638e-03, 3.5259e-04, 7.1787e-05]],
#
#         [[1.6688e-03, 3.1962e-04, 1.5671e-04]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([0.0020, 0.0019, 0.0017], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([0, 3, 6], device='cuda:0')
# tensor([0, 1, 2], device='cuda:0')
# -----build next search-----
# tensor([3, 3, 3], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3], [0, 3, 169, 139, 3, 755, 39, 3], [0, 3, 169, 139, 3, 453, 39, 3]]
# tensor([0.0020, 0.0019, 0.0017], device='cuda:0', grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[ 33,  40, 442]],
#
#         [[755, 453, 899]],
#
#         [[755, 397, 453]]], device='cuda:0')
# -----PPPPPP-----
# tensor([0.0020, 0.0019, 0.0017], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([[[4.1061e-04, 1.2865e-04, 1.1464e-04]],
#
#         [[1.2084e-04, 7.7676e-05, 7.5855e-05]],
#
#         [[2.6178e-04, 1.5400e-04, 1.1745e-04]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([0.0004, 0.0003, 0.0002], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([0, 6, 7], device='cuda:0')
# tensor([0, 2, 2], device='cuda:0')
# -----build next search-----
# tensor([ 33, 755, 397], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33], [0, 3, 169, 139, 3, 453, 39, 3, 755], [0, 3, 169, 139, 3, 453, 39, 3, 397]]
# tensor([0.0004, 0.0003, 0.0002], device='cuda:0', grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[18,  1, 21]],
#
#         [[18,  1, 39]],
#
#         [[18,  1, 39]]], device='cuda:0')
# -----PPPPPP-----
# tensor([0.0004, 0.0003, 0.0002], device='cuda:0', grad_fn=<TopkBackward>)
# tensor([[[2.2967e-04, 8.3249e-05, 1.3672e-05]],
#
#         [[1.1878e-04, 4.0868e-05, 1.1711e-05]],
#
#         [[6.8908e-05, 2.5249e-05, 1.1689e-05]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([2.2967e-04, 1.1878e-04, 8.3249e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([0, 3, 1], device='cuda:0')
# tensor([0, 1, 0], device='cuda:0')
# -----build next search-----
# tensor([18, 18,  1], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18], [0, 3, 169, 139, 3, 453, 39, 3, 755, 18], [0, 3, 169, 139, 3, 755, 54, 3, 33, 1]]
# tensor([2.2967e-04, 1.1878e-04, 8.3249e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  1,  18,   3]],
#
#         [[  1,  18,   3]],
#
#         [[ 18, 161,   3]]], device='cuda:0')
# -----PPPPPP-----
# tensor([2.2967e-04, 1.1878e-04, 8.3249e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[2.2882e-04, 4.2439e-07, 2.5991e-08]],
#
#         [[1.1831e-04, 1.7602e-07, 2.2781e-08]],
#
#         [[2.5613e-05, 1.1723e-05, 7.5555e-06]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([2.2882e-04, 1.1831e-04, 2.5613e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([0, 3, 6], device='cuda:0')
# tensor([0, 1, 2], device='cuda:0')
# -----build next search-----
# tensor([ 1,  1, 18], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1], [0, 3, 169, 139, 3, 453, 39, 3, 755, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 1, 18]]
# tensor([2.2882e-04, 1.1831e-04, 2.5613e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[   1,   18,  161]],
#
#         [[   1,   18,    3]],
#
#         [[   1,   18, 1073]]], device='cuda:0')
# -----PPPPPP-----
# tensor([2.2882e-04, 1.1831e-04, 2.5613e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[1.2538e-04, 7.1017e-05, 3.1043e-06]],
#
#         [[7.4676e-05, 2.5867e-05, 1.7074e-06]],
#
#         [[2.5498e-05, 5.7714e-08, 7.0136e-09]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([1.2538e-04, 7.4676e-05, 7.1017e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([0, 3, 1], device='cuda:0')
# tensor([0, 1, 0], device='cuda:0')
# -----build next search-----
# tensor([ 1,  1, 18], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1], [0, 3, 169, 139, 3, 453, 39, 3, 755, 18, 1, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 18]]
# tensor([1.2538e-04, 7.4676e-05, 7.1017e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  18,    1,  161]],
#
#         [[  18,    1,  161]],
#
#         [[   1,   18, 1073]]], device='cuda:0')
# -----PPPPPP-----
# tensor([1.2538e-04, 7.4676e-05, 7.1017e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[6.5711e-05, 2.5482e-05, 6.2713e-06]],
#
#         [[3.2839e-05, 1.8241e-05, 4.5152e-06]],
#
#         [[7.0829e-05, 1.0497e-07, 1.3341e-08]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([7.0829e-05, 6.5711e-05, 3.2839e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([6, 0, 3], device='cuda:0')
# tensor([2, 0, 1], device='cuda:0')
# -----build next search-----
# tensor([ 1, 18, 18], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18], [0, 3, 169, 139, 3, 453, 39, 3, 755, 18, 1, 1, 18]]
# tensor([7.0829e-05, 6.5711e-05, 3.2839e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[   1,   18,  161]],
#
#         [[   1,   18, 1073]],
#
#         [[   1,   18, 1073]]], device='cuda:0')
# -----PPPPPP-----
# tensor([7.0829e-05, 6.5711e-05, 3.2839e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[4.1169e-05, 2.1983e-05, 8.7976e-07]],
#
#         [[6.5488e-05, 1.2316e-07, 1.9152e-08]],
#
#         [[3.2746e-05, 5.2556e-08, 5.9452e-09]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([6.5488e-05, 4.1169e-05, 3.2746e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([3, 0, 6], device='cuda:0')
# tensor([1, 0, 2], device='cuda:0')
# -----build next search-----
# tensor([1, 1, 1], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 18, 1, 1], [0, 3, 169, 139, 3, 453, 39, 3, 755, 18, 1, 1, 18, 1]]
# tensor([6.5488e-05, 4.1169e-05, 3.2746e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  1,  18, 161]],
#
#         [[ 18,   1, 161]],
#
#         [[  1,  18, 161]]], device='cuda:0')
# -----PPPPPP-----
# tensor([6.5488e-05, 4.1169e-05, 3.2746e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[3.4509e-05, 2.2479e-05, 1.1475e-06]],
#
#         [[2.3761e-05, 8.5705e-06, 1.5877e-06]],
#
#         [[1.8576e-05, 1.0008e-05, 6.0248e-07]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([3.4509e-05, 2.3761e-05, 2.2479e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([0, 3, 1], device='cuda:0')
# tensor([0, 1, 0], device='cuda:0')
# -----build next search-----
# tensor([ 1, 18, 18], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 18, 1, 1, 18], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 18]]
# tensor([3.4509e-05, 2.3761e-05, 2.2479e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  18,    1,  161]],
#
#         [[   1,   18, 1073]],
#
#         [[   1,   18, 1073]]], device='cuda:0')
# -----PPPPPP-----
# tensor([3.4509e-05, 2.3761e-05, 2.2479e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[2.0324e-05, 6.3840e-06, 1.4001e-06]],
#
#         [[2.3682e-05, 4.4645e-08, 6.2795e-09]],
#
#         [[2.2418e-05, 3.5333e-08, 4.6841e-09]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([2.3682e-05, 2.2418e-05, 2.0324e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([3, 6, 0], device='cuda:0')
# tensor([1, 2, 0], device='cuda:0')
# -----build next search-----
# tensor([ 1,  1, 18], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 18, 1, 1, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18]]
# tensor([2.3682e-05, 2.2418e-05, 2.0324e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[   1,   18,  161]],
#
#         [[   1,   18,  161]],
#
#         [[   1,   18, 1073]]], device='cuda:0')
# -----PPPPPP-----
# tensor([2.3682e-05, 2.2418e-05, 2.0324e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[1.1926e-05, 8.7790e-06, 3.8097e-07]],
#
#         [[1.1832e-05, 8.0260e-06, 3.1076e-07]],
#
#         [[2.0251e-05, 4.0015e-08, 6.3528e-09]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([2.0251e-05, 1.1926e-05, 1.1832e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([6, 0, 3], device='cuda:0')
# tensor([2, 0, 1], device='cuda:0')
# -----build next search-----
# tensor([1, 1, 1], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 18, 1, 1, 18, 1, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 18, 1, 1]]
# tensor([2.0251e-05, 1.1926e-05, 1.1832e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  1,  18, 161]],
#
#         [[ 18,   1, 161]],
#
#         [[ 18,   1, 161]]], device='cuda:0')
# -----PPPPPP-----
# tensor([2.0251e-05, 1.1926e-05, 1.1832e-05], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[9.8718e-06, 7.6898e-06, 3.3098e-07]],
#
#         [[7.2167e-06, 2.0783e-06, 4.2207e-07]],
#
#         [[7.2220e-06, 2.1687e-06, 3.9200e-07]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([9.8718e-06, 7.6898e-06, 7.2220e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([0, 1, 6], device='cuda:0')
# tensor([0, 0, 2], device='cuda:0')
# -----build next search-----
# tensor([ 1, 18, 18], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 18], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 18, 1, 1, 18]]
# tensor([9.8718e-06, 7.6898e-06, 7.2220e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  18,    1,  161]],
#
#         [[   1,   18, 1073]],
#
#         [[   1,   18, 1073]]], device='cuda:0')
# -----PPPPPP-----
# tensor([9.8718e-06, 7.6898e-06, 7.2220e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[5.8702e-06, 1.6646e-06, 3.5612e-07]],
#
#         [[7.6687e-06, 1.1873e-08, 1.6367e-09]],
#
#         [[7.1977e-06, 1.3415e-08, 2.0355e-09]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([7.6687e-06, 7.1977e-06, 5.8702e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([3, 6, 0], device='cuda:0')
# tensor([1, 2, 0], device='cuda:0')
# -----build next search-----
# tensor([ 1,  1, 18], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 18, 1, 1, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 1, 18]]
# tensor([7.6687e-06, 7.1977e-06, 5.8702e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[   1,   18,  161]],
#
#         [[   1,   18,  161]],
#
#         [[   1,   18, 1073]]], device='cuda:0')
# -----PPPPPP-----
# tensor([7.6687e-06, 7.1977e-06, 5.8702e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[3.9456e-06, 2.8110e-06, 9.9740e-08]],
#
#         [[3.5295e-06, 2.7152e-06, 1.1029e-07]],
#
#         [[5.8487e-06, 1.1315e-08, 2.1119e-09]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([5.8487e-06, 3.9456e-06, 3.5295e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([6, 0, 3], device='cuda:0')
# tensor([2, 0, 1], device='cuda:0')
# -----build next search-----
# tensor([1, 1, 1], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 1, 18, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 18, 1, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 18, 1, 1, 18, 1, 1]]
# tensor([5.8487e-06, 3.9456e-06, 3.5295e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# torch.Size([3, 1, 9955])
# tensor([[[  1,  18, 161]],
#
#         [[ 18,   1,  46]],
#
#         [[ 18,   1,  46]]], device='cuda:0')
# -----PPPPPP-----
# tensor([5.8487e-06, 3.9456e-06, 3.5295e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([[[2.8079e-06, 2.1738e-06, 9.5723e-08]],
#
#         [[2.3250e-06, 7.1016e-07, 1.3657e-07]],
#
#         [[2.0472e-06, 6.0627e-07, 1.3545e-07]]], device='cuda:0',
#        grad_fn=<MulBackward0>)
# tensor([2.8079e-06, 2.3250e-06, 2.1738e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# tensor([0, 3, 1], device='cuda:0')
# tensor([0, 1, 0], device='cuda:0')
# -----build next search-----
# tensor([ 1, 18, 18], device='cuda:0')
# [[0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 1, 18, 1, 1], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 18, 1, 1, 18], [0, 3, 169, 139, 3, 755, 54, 3, 33, 18, 1, 1, 18, 1, 1, 18, 1, 1, 18, 1, 18]]
# tensor([2.8079e-06, 2.3250e-06, 2.1738e-06], device='cuda:0',
#        grad_fn=<TopkBackward>)
# --another round--
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-335-fac7c9a8fd3d> in <module>
# ----> 1 get_prediction()
#
# <ipython-input-334-25d86cc16b97> in get_prediction()
#       7     features = encoder(image).unsqueeze(1)
#       8     output = decoder.sample(features)
# ----> 9     sentence = clean_sentence(output)
#      10     print(sentence)
#
# <ipython-input-332-2dded52280a1> in clean_sentence(output)
#       1 # TODO #4: Complete the function.
#       2 def clean_sentence(output):
# ----> 3     word_list = [data_loader.dataset.vocab.idx2word[int(i)] for i in output]
#       4     s = ' '
#       5     sentence = s.join(word_list)
#
# <ipython-input-332-2dded52280a1> in <listcomp>(.0)
#       1 # TODO #4: Complete the function.
#       2 def clean_sentence(output):
# ----> 3     word_list = [data_loader.dataset.vocab.idx2word[int(i)] for i in output]
#       4     s = ' '
#       5     sentence = s.join(word_list)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %% [markdown]
# As the last task in this project, you will loop over the images until you find four image-caption pairs of interest:
# - Two should include image-caption pairs that show instances when the model performed well.
# - Two should highlight image-caption pairs that highlight instances where the model did not perform well.
#
# Use the four code cells below to complete this task.

# %% [markdown]
# ### The model performed well!
#
# Use the next two code cells to loop over captions.  Save the notebook when you encounter two images with relatively accurate captions.

# %%
get_prediction()

# %%
get_prediction()

# %% [markdown]
# ### The model could have performed better ...
#
# Use the next two code cells to loop over captions.  Save the notebook when you encounter two images with relatively inaccurate captions.

# %%
get_prediction()

# %%
get_prediction()
